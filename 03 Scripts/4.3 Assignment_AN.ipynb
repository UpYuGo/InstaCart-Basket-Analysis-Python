# %% [markdown]
# # Import libraries

# %%
# 3) Import libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# 4) Turn your project folder path into a string as outlined in the Exercise text.

# %%
# simplify: assigne file-path to 'path' 
path = r'C:\Users\nanh9\10.10.2024 Instacart Basket Analysis'

# %%
path
# Out:
# 'C:\\Users\\nanh9\\10.10.2024 Instacart Basket Analysis'

# %%
df = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'orders.csv'), index_col = False)

# %% [markdown]
# 5) Import the “orders.csv” data set into your notebook using the os library and the vars_list shortcut, omitting the “eval_set” column in your final dataframe.

# %%
df.columns
# Out:
# Index(['order_id', 'user_id', 'eval_set', 'order_number', 'order_dow',
#        'order_hour_of_day', 'days_since_prior_order'],
#       dtype='object')

# %%
vars_list = ['order_id', 'user_id', 'order_number', 'order_dow', 'order_hour_of_day', 'days_since_prior_order']

# %%
df = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'orders.csv'),usecols = vars_list)

# %% [markdown]
# 6) Print the first 5 rows of your dataframe.

# %%
df.head(5)
# Out:
#    order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1             1          2                  8
# 1   2398795        1             2          3                  7
# 2    473747        1             3          3                 12
# 3   2254736        1             4          4                  7
# 4    431534        1             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %% [markdown]
# 7) Import the “products.csv” file into Jupyter as df_prods (as opposed to df, which is what your “orders.csv” file is named in Jupyter). You can use the path variable you created in step 4 to import “products.csv” with the os library.

# %%
path = r'C:\Users\nanh9\10.10.2024 Instacart Basket Analysis'

# %%
path
# Out:
# 'C:\\Users\\nanh9\\10.10.2024 Instacart Basket Analysis'

# %%
df_prods = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'products.csv'), index_col = False)

# %% [markdown]
# 8) Print the first 20 rows and the last 35 rows of the df_prods dataframe.

# %%
df.head(20)
# Out:
#     order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0    2539329        1             1          2                  8
# 1    2398795        1             2          3                  7
# 2     473747        1             3          3                 12
# 3    2254736        1             4          4                  7
# 4     431534        1             5          4                 15
# 5    3367565        1             6          2                  7
# 6     550135        1             7          1                  9
# 7    3108588        1             8          1                 14
# 8    2295261        1             9          1                 16
# 9    2550362        1            10          4                  8
# 10   1187899        1            11          4                  8
# 11   2168274        2             1          2                 11
# 12   1501582        2             2          5                 10
# ...

# %%
df.tail(35)
# Out:
#          order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 3421048    726186   206208            30          0                 16
# 3421049   2523609   206208            31          4                 11
# 3421050    756221   206208            32          6                 18
# 3421051   2254244   206208            33          6                 13
# 3421052   2017995   206208            34          6                 15
# 3421053   2789700   206208            35          3                 22
# 3421054    844592   206208            36          6                 15
# 3421055   1541132   206208            37          2                 12
# 3421056   2808240   206208            38          0                 15
# 3421057   3027766   206208            39          2                 14
# 3421058   3356245   206208            40          5                  9
# 3421059    442304   206208            41          2                 14
# ...

# %% [markdown]
# 9) Print the names of the columns in the df_prods dataframe.

# %%
df_prods.columns
# Out:
# Index(['product_id', 'product_name', 'aisle_id', 'department_id', 'prices'], dtype='object')

# %% [markdown]
# 10) Print the number of rows and columns in the df_prods dataframe.

# %%
df.shape
# Out:
# (3421083, 6)

# %% [markdown]
# 10) Answer the following questions using the relevant commands. Use markdown mode for your Jupyter cells to provide written answers within your Jupyter notebook after executing the commands:
#
# What’s the maximum value of the “aisle_id” column?

# %%
df_prods.describe()
# Out:
#          product_id      aisle_id  department_id        prices
# count  49693.000000  49693.000000   49693.000000  49693.000000
# mean   24844.345139     67.770249      11.728433      9.994136
# std    14343.717401     38.316774       5.850282    453.519686
# min        1.000000      1.000000       1.000000      1.000000
# 25%    12423.000000     35.000000       7.000000      4.100000
# 50%    24845.000000     69.000000      13.000000      7.100000
# 75%    37265.000000    100.000000      17.000000     11.200000
# max    49688.000000    134.000000      21.000000  99999.000000

# %% [markdown]
# Answer: The maximum value of "aisle_id" column is 134.000000

# %% [markdown]
# What’s the data type of the “department_id” column?

# %%
df_prods.dtypes
# Out:
# product_id         int64
# product_name      object
# aisle_id           int64
# department_id      int64
# prices           float64
# dtype: object

# %% [markdown]
# Answer: The data type of the “department_id” column is int64 (Integer)
